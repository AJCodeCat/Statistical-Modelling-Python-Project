

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"message":"Invalid request token."}

# %%
# FSQ LAT LONG LOOP "+str(location[0])+"
#Categories from https://location.foursquare.com/places/docs/categories 
# (4): Mexican, BBQ joints, Cafes, Ice cream parlours

import requests
import pandas as pd

#fsq_df = pd.DataFrame()

for location in cb_locations:
    url = "https://api.foursquare.com/v3/places/search?ll="+str(location[0])+"%2C"+str(location[1])+"&radius=1000&categories=16004%2C%2013059%2C%2013046%20%2C%2016003%2C%2013026&limit=20"

    headers = {"accept": "application/json"}
    
    headers['Authorization'] = api_key

    response = requests.get(url, headers=headers)
    fsqdata = response.json()

    name = []
    categories = []
#     ratings = []
#     review_counts = []

    results = fsqdata['results']
    for result in results:
        name.append(result['name'])
        categories.append(result['categories'][0]['name'])
#         ratings.append(business['rating'])
#         review_counts.append(business['review_count'])

    temp_df = pd.DataFrame({
        'name' : name,
        'categories' : categories,
#         'rating': ratings,
#         'review_count': review_counts,
        'latitude': location[0],
        'longitude': location[1]
    })

    fsq_df = fsq_df.append(temp_df, ignore_index=True)

print(fsq_df)
# Out:
#                                  name        categories   latitude  longitude
# 0                             Charred         BBQ Joint  43.259126 -79.877212
# 1                       Booster Juice         Juice Bar  43.259126 -79.877212
# 2             Lou Dawg's Southern Bbq         BBQ Joint  43.259126 -79.877212
# 3                    Freshly Squeezed         Juice Bar  43.259126 -79.877212
# 4                 Saltlick Smokehouse         BBQ Joint  43.259126 -79.877212
# ..                                ...               ...        ...        ...
# 439                        Big Scoops  Ice Cream Parlor  43.257392 -79.867902
# 440           Lou Dawg's Southern Bbq         BBQ Joint  43.257392 -79.867902
# 441               Willard's Ice Cream  Ice Cream Parlor  43.257392 -79.867902
# 442  Cho Sun Ok Korean BBQ Restaurant         BBQ Joint  43.257392 -79.867902
# 443                   K W BBQ Kitchen         BBQ Joint  43.257392 -79.867902
#
# [444 rows x 4 columns]

# %%
response.json()
# Out:
# {'results': [{'fsq_id': '520e97ce498e3ee7817abaf4',
#    'categories': [{'id': 13026,
#      'name': 'BBQ Joint',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'}},
#     {'id': 13325,
#      'name': 'Portuguese Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 617,
#    'geocodes': {'drop_off': {'latitude': 43.262818, 'longitude': -79.866365},
#     'main': {'latitude': 43.262759, 'longitude': -79.866231},
#     'roof': {'latitude': 43.262759, 'longitude': -79.866231}},
#    'link': '/v3/places/520e97ce498e3ee7817abaf4',
#    'location': {'address': '244 James St N',
#     'country': 'CA',
#     'cross_street': 'btwn Robert St & Colbourne St',
#     'formatted_address': '244 James St N (btwn Robert St & Colbourne St), Hamilton ON L8R 2L3',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 2L3',
# ...

# %%
fsqdata = response.json()

# %%
fsqdata.keys()
# Out:
# dict_keys(['message'])

# %%
# Make a list to make into a DF 
fsq_list = []
for fsq_info in fsqdata['results']:
    fsq_list.append([fsq_info['name'], fsq_info['categories'][0]['name'], fsq_info['geocodes']['main']['latitude'], fsq_info['geocodes']['main']['longitude']])

# %%
fsq_list
# Out:
# [['Charred', 'BBQ Joint', 43.262759, -79.866231],
#  ['Saltlick Smokehouse', 'BBQ Joint', 43.263456, -79.865886],
#  ['Booster Juice', 'Juice Bar', 43.257213, -79.869235],
#  ['Freshly Squeezed', 'Juice Bar', 43.257089, -79.869399],
#  ['Saltlick Smokehouse', 'BBQ Joint', 43.258968, -79.870413],
#  ['Big Scoops', 'Ice Cream Parlor', 43.251894, -79.871488],
#  ["Lou Dawg's Southern Bbq", 'BBQ Joint', 43.258599, -79.878836],
#  ["Willard's Ice Cream", 'Ice Cream Parlor', 43.255291, -79.873129],
#  ['Cho Sun Ok Korean BBQ Restaurant', 'BBQ Joint', 43.26198, -79.877785],
#  ['K W BBQ Kitchen', 'BBQ Joint', 43.262532, -79.877879]]

# %%
# Build the DF
import pandas as pd
fsq_df = pd.DataFrame(data=fsq_list, columns=['name', 'categories', 'latitude', 'longitude'])

# %%
fsq_df
# Out:
#                                name        categories   latitude  longitude
# 0                           Charred         BBQ Joint  43.262759 -79.866231
# 1               Saltlick Smokehouse         BBQ Joint  43.263456 -79.865886
# 2                     Booster Juice         Juice Bar  43.257213 -79.869235
# 3                  Freshly Squeezed         Juice Bar  43.257089 -79.869399
# 4               Saltlick Smokehouse         BBQ Joint  43.258968 -79.870413
# 5                        Big Scoops  Ice Cream Parlor  43.251894 -79.871488
# 6           Lou Dawg's Southern Bbq         BBQ Joint  43.258599 -79.878836
# 7               Willard's Ice Cream  Ice Cream Parlor  43.255291 -79.873129
# 8  Cho Sun Ok Korean BBQ Restaurant         BBQ Joint  43.261980 -79.877785
# 9                   K W BBQ Kitchen         BBQ Joint  43.262532 -79.877879

# %%
# EXPOT DATAFRAME TO CSV FILE
import pandas as pd
fsq_df.to_csv('C:/Career/LighthouseLabs/PythonProject_Week5/fsq_df.csv')

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# PATH to FSQ ID, list 0-19, n = 20
fsqdata['results'][0]['fsq_id']

# PATH to NAME, list 0-19, n = 20
fsqdata['results'][0]['name']

# PATH to LATITUDE, list 0-19, n = 20
fsqdata['results'][0]['geocodes']['main']['latitude']

# PATH to LONGITUDE, list 0-19, n = 20
fsqdata['results'][0]['geocodes']['main']['longitude']

# PATH to CATEGORIES NAME, list 0-19, n = 20
fsqdata['results'][0]['categories'][0]['name']

# %% [markdown]
# Put your parsed results into a DataFrame

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
import requests
from IPython.display import JSON 
import argparse
import json
import pprint
import sys
import urllib
import pandas as pd

# %%
# get network data
#city_bike_networks = requests.get("http://api.citybik.es/v2/networks").json()
yelp = requests.get('https://api.yelp.com/v3/categories/Restaurants&Museums&Aquariums&Planetarium&Beaches').json()

# view json in nice format
#JSON(city_bike_networks)

# %%
# import requests

# url = "http://api.citybik.es/v2/networks"
# response = requests.get(url)

# if response.status_code == 200:
#     data = response.json()
#     print(data)
# else:
#     print("Error fetching data:", response.status_code)

# %%
# YELP FUSION PYTHON
# SINGLE LAT LONG YELP GET
# Newest Categories: Ice cream, food trucks, food stands, beaches, bicycle paths
#import requests

url = "https://api.yelp.com/v3/businesses/search?latitude=43.259125842121065&longitude=-79.87721174955368&radius=1000&categories=icecream&categories=foodtrucks&categories=beaches&categories=foodstands&categories=bicyclepaths&sort_by=best_match&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer x8n4Tf1ybTXh2mpCf-99AtZSEJBIui85zStpVQhq4naAyVl1pCN--oKZN8GkJrw8KyTOtJ9JxF9PACz_qAuXhZU3F0uBJ_02bDAL0CBx1b-CqeY2IVC9eybyOBd8ZHYx"
}

response = requests.get(url, headers=headers)

print(response.text)


# url = "https://api.yelp.com/v3/businesses/search?latitude=43.259125842121065&longitude=-79.87721174955368&radius=1000&categories=Restaurants&categories=Planetarium&categories=Aquariums&categories=Museums&categories=Beaches&categories=Botanical%20Gardens&categories=Bike%20Parking&categories=Bicycle%20Paths&sort_by=best_match&limit=20"

# headers = {
#     "accept": "application/json",
#     "Authorization": "Bearer x8n4Tf1ybTXh2mpCf-99AtZSEJBIui85zStpVQhq4naAyVl1pCN--oKZN8GkJrw8KyTOtJ9JxF9PACz_qAuXhZU3F0uBJ_02bDAL0CBx1b-CqeY2IVC9eybyOBd8ZHYx"
# }

# response = requests.get(url, headers=headers)

# print(response.text)
# New Categories
# import requests

# url = "https://api.yelp.com/v3/businesses/search?latitude=43.259125842121065&longitude=-79.87721174955368&radius=1000&categories=Restaurants&categories=Planetarium&categories=Aquariums&categories=Museums&categories=Beaches&categories=Botanical%20Gardens&categories=Bike%20Parking&categories=Bicycle%20Paths&sort_by=best_match&limit=20"

# headers = {
#     "accept": "application/json",
#     "Authorization": "Bearer x8n4Tf1ybTXh2mpCf-99AtZSEJBIui85zStpVQhq4naAyVl1pCN--oKZN8GkJrw8KyTOtJ9JxF9PACz_qAuXhZU3F0uBJ_02bDAL0CBx1b-CqeY2IVC9eybyOBd8ZHYx"
# }

# response = requests.get(url, headers=headers)

# print(response.text)
# Out:
# {"businesses": [{"id": "vqyK2q3zJ74TIT1-7Bf3Tg", "alias": "la-luna-hamilton", "name": "La Luna", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/OBRpyj_wUqmDwKLtKU4pCA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/la-luna-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A", "review_count": 63, "categories": [{"alias": "mideastern", "title": "Middle Eastern"}], "rating": 4.0, "coordinates": {"latitude": 43.25942165323912, "longitude": -79.87848757635106}, "transactions": [], "price": "$$", "location": {"address1": "306 King Street W", "address2": "", "address3": "", "city": "Hamilton", "zip_code": "L8P 1B1", "country": "CA", "state": "ON", "display_address": ["306 King Street W", "Hamilton, ON L8P 1B1", "Canada"]}, "phone": "+19055770233", "display_phone": "+1 905-577-0233", "distance": 108.42454951711392}, {"id": "752Fv2jKafftvoS3Twkqyg", "alias": "hambrgr-hamilton", "name":
# ...

# %%
yelpdata = response.json()
print(yelpdata)
# Out:
# {'businesses': [{'id': 'vqyK2q3zJ74TIT1-7Bf3Tg', 'alias': 'la-luna-hamilton', 'name': 'La Luna', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OBRpyj_wUqmDwKLtKU4pCA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/la-luna-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A', 'review_count': 63, 'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}], 'rating': 4.0, 'coordinates': {'latitude': 43.25942165323912, 'longitude': -79.87848757635106}, 'transactions': [], 'price': '$$', 'location': {'address1': '306 King Street W', 'address2': '', 'address3': '', 'city': 'Hamilton', 'zip_code': 'L8P 1B1', 'country': 'CA', 'state': 'ON', 'display_address': ['306 King Street W', 'Hamilton, ON L8P 1B1', 'Canada']}, 'phone': '+19055770233', 'display_phone': '+1 905-577-0233', 'distance': 108.42454951711392}, {'id': '752Fv2jKafftvoS3Twkqyg', 'alias': 'hambrgr-hamilton', 'name':
# ...

# %%
yelpdata['businesses']
# Out:
# [{'id': 'vqyK2q3zJ74TIT1-7Bf3Tg',
#   'alias': 'la-luna-hamilton',
#   'name': 'La Luna',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OBRpyj_wUqmDwKLtKU4pCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-luna-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A',
#   'review_count': 63,
#   'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.25942165323912,
#    'longitude': -79.87848757635106},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '306 King Street W',
#    'address2': '',
#    'address3': '',
#    'city': 'Hamilton',
#    'zip_code': 'L8P 1B1',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['306 King Street W', 'Hamilton, ON L8P 1B1', 'Canada']},
#   'phone': '+19055770233',
#   'display_phone': '+1 905-577-0233',
# ...

# %%
yelpdata
# Out:
# {'businesses': [{'id': 'h2mI1wBIK1PyaNupaL58gw',
#    'alias': 'the-mule-hamilton',
#    'name': 'The Mule',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto
= "https://api.yelp.com/v3/businesses/search?latitude=43.259125842121065&longitude=-79.87721174955368&radius=1000&categories=Restaurants&categories=Planetarium&categories=Aquariums&categories=Museums&categories=Beaches&categories=Botanical%20Gardens&categories=Bike%20Parking&categories=Bicycle%20Paths&sort_by=best_match&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer x8n4Tf1ybTXh2mpCf-99AtZSEJBIui85zStpVQhq4naAyVl1pCN--oKZN8GkJrw8KyTOtJ9JxF9PACz_qAuXhZU3F0uBJ_02bDAL0CBx1b-CqeY2IVC9eybyOBd8ZHYx"
}

response = requests.get(url, headers=headers)

#print(response.text)

yelpdata = response.json()

yelp_df['rating'] = yelpdata['businesses'][0]['rating']
yelp_df['review_count'] = yelpdata['businesses'][0]['review_count']

# %%
yelpdata['businesses'][0]['review_count']
# Out:
# 63

# %%
yelp_df
# Out:
# Empty DataFrame
# Columns: [rating, review_count]
# Index: []

# %%
import requests
import pandas as pd
yelp_df = pd.DataFrame()

for location in cb_locations:
# New Categories: icecream, foodtrucks, beaches, foodstands, bicyclepaths


url = "https://api.yelp.com/v3/businesses/search?latitude="+str(location[0])+"&longitude="+str(location[1])+"&radius=1000&categories=icecream&categories=foodtrucks&categories=beaches&categories=foodstands&categories=bicyclepaths&sort_by=best_match&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer x8n4Tf1ybTXh2mpCf-99AtZSEJBIui85zStpVQhq4naAyVl1pCN--oKZN8GkJrw8KyTOtJ9JxF9PACz_qAuXhZU3F0uBJ_02bDAL0CBx1b-CqeY2IVC9eybyOBd8ZHYx"
}

response = requests.get(url, headers=headers)

# print(response.text)

#     url = "https://api.yelp.com/v3/businesses/search?latitude="+str(location[0])+"&longitude="+str(location[1])+"&radius=1000&categories=Restaurants&categories=Planetarium&categories=Aquariums&categories=Museums&categories=Beaches&categories=Botanical%20Gardens&categories=Bike%20Parking&categories=Bicycle%20Paths&sort_by=best_match&limit=20"

#     headers = {
#         "accept": "application/json",
#         "Authorization": "Bearer x8n4Tf1ybTXh2mpCf-99AtZSEJBIui85zStpVQhq4naAyVl1pCN--oKZN8GkJrw8KyTOtJ9JxF9PACz_qAuXhZU3F0uBJ_02bDAL0CBx1b-CqeY2IVC9eybyOBd8ZHYx"
#     }

#     response = requests.get(url, headers=headers)

    #print(response.text)

    yelpdata = response.json()

    ratings = []
    review_counts = []

    businesses = yelpdata['businesses']
    for business in businesses:
        ratings.append(business['rating'])
        review_counts.append(business['review_count'])
    
    yelp_df['name'] = name
    yelp_df['categories'] = categories
    yelp_df['rating'] = ratings
    yelp_df['review_count'] = review_counts
    yelp_df['latitude'] = location[0]
    yelp_df['longitude'] = location[1]

    print(yelp_df)
    
# station_list = []
# for station_info in response_info['network']['stations']:
#  station_list.append([station_info['empty_slots'], station_info['free_bikes'], station_info['latitude'], station_info['longitude']])
# Out:
#     rating  review_count   latitude  longitude
# 0      4.0            63  43.259126 -79.877212
# 1      4.5           203  43.259126 -79.877212
# 2      4.0           287  43.259126 -79.877212
# 3      4.0           208  43.259126 -79.877212
# 4      4.0            43  43.259126 -79.877212
# 5      4.0           175  43.259126 -79.877212
# 6      4.5            16  43.259126 -79.877212
# 7      3.5            17  43.259126 -79.877212
# 8      4.0            13  43.259126 -79.877212
# 9      4.0            98  43.259126 -79.877212
# 10     4.0            37  43.259126 -79.877212
# 11     4.5            14  43.259126 -79.877212
# 12     3.5            36  43.259126 -79.877212
# 13     4.5            42  43.259126 -79.877212
# 14     4.0           122  43.259126 -79.877212
# 15     4.0           120  43.259126 -79.877212
# 16     4.5            12  43.259126 -79.877212
# 17     4.0            10  43.259126 -79.877212
# 18     5.0             9  43.259126 -79.877212
# ...

# %%
import requests
import pandas as pd

yelpone_df = pd.DataFrame()

url = "https://api.yelp.com/v3/businesses/search?latitude=43.259125842121065&longitude=-79.87721174955368&radius=1000&categories=Restaurants&categories=Planetarium&categories=Aquariums&categories=Museums&categories=Beaches&categories=Botanical%20Gardens&categories=Bike%20Parking&categories=Bicycle%20Paths&sort_by=best_match&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer x8n4Tf1ybTXh2mpCf-99AtZSEJBIui85zStpVQhq4naAyVl1pCN--oKZN8GkJrw8KyTOtJ9JxF9PACz_qAuXhZU3F0uBJ_02bDAL0CBx1b-CqeY2IVC9eybyOBd8ZHYx"
}

responseone = requests.get(url, headers=headers)
yelponedata = responseone.json()

#name = []
ratings = []
review_counts = []

businesses = yelpdata['businesses']
for business in businesses:
    ratings.append(business['rating'])
    review_counts.append(business['review_count'])

#yelpone_df['rating'] = ratings
#yelpone_df['review_count'] = review_counts

tempone_df = pd.DataFrame({
    #'name' : name,
    #'categories' : categories,
    'rating': ratings,
    'review_count': review_counts,
    'latitude': location[0],
    'longitude': location[1]
})

yelpone_df = yelpone_df.append(tempone_df, ignore_index=True)

print(yelpone_df)
# Out:
#     rating  review_count   latitude  longitude
# 0      4.0           175  43.257392 -79.867902
# 1      4.5            22  43.257392 -79.867902
# 2      4.0            44  43.257392 -79.867902
# 3      4.5            57  43.257392 -79.867902
# 4      4.0            74  43.257392 -79.867902
# 5      4.5             8  43.257392 -79.867902
# 6      4.5            12  43.257392 -79.867902
# 7      4.5            13  43.257392 -79.867902
# 8      4.0            23  43.257392 -79.867902
# 9      4.0            57  43.257392 -79.867902
# 10     4.5             7  43.257392 -79.867902
# 11     4.5            14  43.257392 -79.867902
# 12     4.5             2  43.257392 -79.867902
# 13     4.0            10  43.257392 -79.867902
# 14     4.5            12  43.257392 -79.867902
# 15     1.0             1  43.257392 -79.867902
# 16     4.5             8  43.257392 -79.867902
# 17     3.5             7  43.257392 -79.867902
# 18     3.5            20  43.257392 -79.867902
# ...

# %%
yelp_df
# Out:
# Empty DataFrame
# Columns: [rating, review_count]
# Index: []

# %%
for location in cb_locations:
    print(location[1])
# Out:
# -79.87721174955368
# -79.87132698297499
# -79.8679232597351
# -79.87180307507515
# -79.8744987564414
# -79.8753935613187
# -79.8720555723035
# -79.8777937889099
# -79.877606006297
# -79.8561337635964
# -79.91580605506897
# -79.82740849256516
# -79.8819466027797
# -79.87889617681503
# -79.8388883471489
# -79.82685998082161
# -79.8827367298478
# -79.8819495909127
# -79.8836993988543
# -79.88798081874847
# -79.8892092704773
# -79.8909067737901
# -79.92224670946598
# -79.91824820637703
# -79.922358671032
# -79.91978779435158
# -79.8993094512
# -79.9009418422827
# -79.90823779724
# -79.9011692404747
# -79.8964982026467
# -79.89265590906143
# -79.8947787566411
# -79.94765996932983
# -79.8945270389426
# -79.88345324993132
# -79.9208028150996
# -79.90508794784544
# -79.90359663963316
# -79.9222158171462
# -79.9133658840373
# -79.91026729345322
# -79.9264810904732
# -79.9092948353051
# -79.9166152756283
# -79.90785866975784
# -79.95375394821166
# -79.86948698759079
# -79.8749090863127
# ...

# %%
# FINAL FORM # FINAL FORM # FINAL FORM # FINAL FORM # FINAL FORM # FINAL FORM # FINAL FORM # FINAL FORM # FINAL FORM
import warnings

# Block future warnings
warnings.simplefilter(action='ignore', category=FutureWarning)


#sample code:
import requests
import pandas as pd

yelp_df = pd.DataFrame()

#for location in cb_locations:
# New Categories (7): icecream, Mexicans, BBQ, cafes

for location in cb_locations:

    url = "https://api.yelp.com/v3/businesses/search?latitude="+str(location[0])+"&longitude="+str(location[1])+"&radius=1000&categories=BBQ&categories=mexican&categories=icecream&categories=cafes&sort_by=best_match&limit=20"

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer E0bmwJggGAi3ZgrtbYGT3ITMYpCCYkXRuiWvR4wwSsQcecFZ7HEU7wTqJjAQAM2ZYxmtOe505O3bN4PV8iAz-w2sd9s0725XVc4fAaQCoxIoybFd33juOvTx9R97ZHYx" }

    response = requests.get(url, headers=headers)


    yelpdata = response.json()

    #name = []
    #categories = []
    ratings = []
    review_counts = []

    businesses = yelpdata['businesses']
    for business in businesses:
        #name.append(business['name'])
        #categories.append(business['categories'])
        ratings.append(business['rating'])
        review_counts.append(business['review_count'])

    temp_df = pd.DataFrame({
        #'name' : name,
        #'categories' : categories,
        'rating': ratings,
        'review_count': review_counts,
        'latitude': location[0],
        'longitude': location[1]
    })

    yelp_df = yelp_df.append(temp_df, ignore_index=True)

print(yelp_df)
# Out:
#       rating  review_count   latitude  longitude
# 0        4.0         175.0  43.259126 -79.877212
# 1        4.5          14.0  43.259126 -79.877212
# 2        4.0          10.0  43.259126 -79.877212
# 3        4.5          57.0  43.259126 -79.877212
# 4        4.5          22.0  43.259126 -79.877212
# ...      ...           ...        ...        ...
# 1218     3.5          20.0  43.257392 -79.867902
# 1219     3.5           7.0  43.257392 -79.867902
# 1220     1.0           1.0  43.257392 -79.867902
# 1221     4.5           8.0  43.257392 -79.867902
# 1222     3.5           6.0  43.257392 -79.867902
#
# [1223 rows x 4 columns]

# %%
response
# Out:
# <Response [200]>

# %%
yelpdata
# Out:
# {'businesses': [{'id': 'h2mI1wBIK1PyaNupaL58gw',
#    'alias': 'the-mule-hamilton',
#    'name': 'The Mule',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F2fno9iYekGXrKq8cFQYmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mule-hamilton?adjust_creative=yFWeVz8UGIGNocCyw6wXdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yFWeVz8UGIGNocCyw6wXdw',
#    'review_count': 175,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.25726, 'longitude': -79.86713},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['41 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893892555',
# ...

# %%
yelp_df
# Out:
#     rating  review_count   latitude  longitude
# 0      4.0           175  43.257392 -79.867902
# 1      4.5            22  43.257392 -79.867902
# 2      4.0            44  43.257392 -79.867902
# 3      4.5            57  43.257392 -79.867902
# 4      4.0            74  43.257392 -79.867902
# 5      4.5             8  43.257392 -79.867902
# 6      4.5            13  43.257392 -79.867902
# 7      4.5            12  43.257392 -79.867902
# 8      4.0            23  43.257392 -79.867902
# 9      4.0            57  43.257392 -79.867902
# 10     4.5             7  43.257392 -79.867902
# 11     4.0            10  43.257392 -79.867902
# 12     4.5            14  43.257392 -79.867902
# 13     4.5             2  43.257392 -79.867902
# 14     4.5            12  43.257392 -79.867902
# 15     3.5            20  43.257392 -79.867902
# 16     3.5             7  43.257392 -79.867902
# 17     1.0             1  43.257392 -79.867902
# 18     4.5             8  43.257392 -79.867902
# ...

# %%
# TRY ONE (still hates = yelpdata['businesses'])
yelp_df = pd.DataFrame()

#for location in cb_locations:
# New Categories (7): icecream, foodtrucks, beaches, foodstands, bicyclepaths, BBQ, juicebars

for location in cb_locations:
    url = "https://api.yelp.com/v3/businesses/search?latitude=43.2573917915248&longitude=-79.86790180206299&radius=1000&categories=icecream&categories=foodtrucks&categories=beaches&categories=foodstands&categories=bicyclepaths&categories=BBQ&categories=juicebars&sort_by=best_match&limit=20"

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer x8n4Tf1ybTXh2mpCf-99AtZSEJBIui85zStpVQhq4naAyVl1pCN--oKZN8GkJrw8KyTOtJ9JxF9PACz_qAuXhZU3F0uBJ_02bDAL0CBx1b-CqeY2IVC9eybyOBd8ZHYx"
    }

response = requests.get(url, headers=headers)

yelpdata = response.json()

name = []
categories = []
ratings = []
review_counts = []

businesses = yelpdata['businesses']
for business in businesses:
    name.append(business['name'])
    categories.append(business['categories'])
    ratings.append(business['rating'])
    review_counts.append(business['review_count'])

temp_df = pd.DataFrame({
    'name' : name,
    'categories' : categories,
    'rating': ratings,
    'review_count': review_counts,
    'latitude': location[0],
    'longitude': location[1]
})

yelp_df = yelp_df.append(temp_df, ignore_index=True)

print(yelp_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[121], line 23
#      20 ratings = []
#      21 review_counts = []
# ---> 23 businesses = yelpdata['businesses']
#      24 for business in businesses:
#      25     name.append(business['name'])
#
# KeyError: 'businesses'

# %%
# Make a list to make into a DF once the GET works
yelp_list = []
for yelp_info in yelpdata['businesses']:
    yelp_list.append([yelp_info['name'], yelp_info['categories'], yelp_info['rating'], yelp_info['review_count'], yelp_info['coordinates']['latitude'], yelp_info['coordinates']['longitude']])

# %%
# Create the Pandas DF
import pandas as pd
yelp_df = pd.DataFrame(data=yelp_list, columns=['name', 'categories', 'rating', 'review_count', 'latitude', 'longitude'])

# %%
yelp_df
# Out:
#                                            name  \
# 0                                      The Mule
# 1                      Redchurch Cafe + Gallery
# 2                                  Burrito Boyz
# 3             Saint James Espresso Bar & Eatery
# 4                          Mulberry Coffeehouse
# 5                Rita's Italian Ice And Custard
# 6                                       Synonym
# 7                               Red Crow Coffee
# 8                                   Cafe Oranje
# 9                                          Mesa
# 10  Henry Brown's Small Batch Ice Cream Company
# 11                               Ark and Anchor
# 12                        Latin Food & Products
# 13                          Papagayo Restaurant
# 14                                       Amigos
# 15                                 Laura Secord
# 16                             A & J Sugar Bowl
# 17                            Dunas Verdes Cafe
# ...

# %%
# Out:
# {'error': {'code': 'REQUEST_TIMED_OUT',
#   'description': "The request timed out, please try again later. If this continues, please create an issue on GitHub with the request you're making: https://github.com/Yelp/yelp-fusion/issues"}}

# %%
yelp_df.to_csv('C:\Career\LighthouseLabs\PythonProject_Week5\yelp_df.csv')

# %%
yelp_df
# Out:
#       rating  review_count   latitude  longitude
# 0        4.0            63  43.259126 -79.877212
# 1        4.5           203  43.259126 -79.877212
# 2        4.0           287  43.259126 -79.877212
# 3        4.0           208  43.259126 -79.877212
# 4        4.0            43  43.259126 -79.877212
# ...      ...           ...        ...        ...
# 2875     4.0           120  43.257392 -79.867902
# 2876     4.5            12  43.257392 -79.867902
# 2877     4.0            10  43.257392 -79.867902
# 2878     5.0             9  43.257392 -79.867902
# 2879     4.5            39  43.257392 -79.867902
#
# [2880 rows x 4 columns]

# %%
yelp_df
# Out:
#       rating  review_count   latitude  longitude
# 0        4.0            63  43.259126 -79.877212
# 1        4.5           203  43.259126 -79.877212
# 2        4.0           287  43.259126 -79.877212
# 3        4.0           208  43.259126 -79.877212
# 4        4.0            43  43.259126 -79.877212
# ...      ...           ...        ...        ...
# 2355     4.0           120  43.256905 -79.866435
# 2356     4.5            12  43.256905 -79.866435
# 2357     4.0            10  43.256905 -79.866435
# 2358     5.0             9  43.256905 -79.866435
# 2359     4.5            39  43.256905 -79.866435
#
# [2360 rows x 4 columns]

# %%
url = "https://api.yelp.com/v3/businesses/search?latitude=43.259125842121065&longitude=-79.87721174955368&radius=1000&categories=Restaurants&categories=Planetarium&categories=Aquariums&categories=Museums&categories=Beaches&categories=Botanical%20Gardens&categories=Bike%20Parking&categories=Bicycle%20Paths&sort_by=best_match&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "Bear
# %%
latlong
# Out:
# 'latitude=[lll[][0]]&longitude=[lll[][1]]'

# %%
yelpget(url,latlong,rest)

def yelpget(url,latlong,rest):
    for i in range(len(lll)):
        print('{}{}{}{}{}'.format(url, latlist, moreurl, longlist, rest))
# Out:
# https://api.yelp.com/v3/businesses/search?latitude=latitude=[lll[][0]]&longitude=[lll[][1]]&radius=1000&categories=Restaurants&categories=Planetarium&categories=Aquariums&categories=Museums&categories=Beaches&categories=Botanical%20Gardens&categories=Bike%20Parking&categories=Bicycle%20Paths&sort_by=best_match&limit=20
# https://api.yelp.com/v3/businesses/search?latitude=latitude=[lll[][0]]&longitude=[lll[][1]]&radius=1000&categories=Restaurants&categories=Planetarium&categories=Aquariums&categories=Museums&categories=Beaches&categories=Botanical%20Gardens&categories=Bike%20Parking&categories=Bicycle%20Paths&sort_by=best_match&limit=20
# https://api.yelp.com/v3/businesses/search?latitude=latitude=[lll[][0]]&longitude=[lll[][1]]&radius=1000&categories=Restaurants&categories=Planetarium&categories=Aquariums&categories=Museums&categories=Beaches&categories=Botanical%20Gardens&categories=Bike%20Parking&categories=Bicycle%20Paths&sort_by=best_match&limit=20
# ...

# %%
# From Fusion: Results of GET
{
  "businesses": [
    {
      "id": "vqyK2q3zJ74TIT1-7Bf3Tg",
      "alias": "la-luna-hamilton",
      "name": "La Luna",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/OBRpyj_wUqmDwKLtKU4pCA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/la-luna-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 63,
      "categories": [
        {
          "alias": "mideastern",
          "title": "Middle Eastern"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.25942165323912,
        "longitude": -79.87848757635106
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "306 King Street W",
        "address2": "",
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8P 1B1",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "306 King Street W",
          "Hamilton, ON L8P 1B1",
          "Canada"
        ]
      },
      "phone": "+19055770233",
      "display_phone": "+1 905-577-0233",
      "distance": 108.42454951711392
    },
    {
      "id": "9oIPWjU3DvtSdORv6I2toQ",
      "alias": "the-ship-hamilton",
      "name": "The Ship",
      "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Fikmd2hYPI16m5eIhSlszQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/the-ship-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 208,
      "categories": [
        {
          "alias": "seafood",
          "title": "Seafood"
        },
        {
          "alias": "pubs",
          "title": "Pubs"
        },
        {
          "alias": "burgers",
          "title": "Burgers"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.25215,
        "longitude": -79.87
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "23 Augusta Street",
        "address2": "",
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8N 1P6",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "23 Augusta Street",
          "Hamilton, ON L8N 1P6",
          "Canada"
        ]
      },
      "phone": "+19055260792",
      "display_phone": "+1 905-526-0792",
      "distance": 970.855527645918
    },
    {
      "id": "h2mI1wBIK1PyaNupaL58gw",
      "alias": "the-mule-hamilton",
      "name": "The Mule",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/F2fno9iYekGXrKq8cFQYmw/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/the-mule-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 175,
      "categories": [
        {
          "alias": "mexican",
          "title": "Mexican"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.25726,
        "longitude": -79.86713
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "41 King William Street",
        "address2": null,
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8R 1A2",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "41 King William Street",
          "Hamilton, ON L8R 1A2",
          "Canada"
        ]
      },
      "phone": "+12893892555",
      "display_phone": "+1 289-389-2555",
      "distance": 833.7234169860423
    },
    {
      "id": "Q4oLgsU62VPR28pBm0vCXw",
      "alias": "earth-to-table-bread-bar-hamilton",
      "name": "Earth To Table : Bread Bar",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/t-G4g7Hq1wH4ZIWSB-a56g/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/earth-to-table-bread-bar-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 287,
      "categories": [
        {
          "alias": "pizza",
          "title": "Pizza"
        },
        {
          "alias": "breakfast_brunch",
          "title": "Breakfast & Brunch"
        },
        {
          "alias": "salad",
          "title": "Salad"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.25284,
        "longitude": -79.88702
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "258 Locke Street S",
        "address2": "",
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8P 4B9",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "258 Locke Street S",
          "Hamilton, ON L8P 4B9",
          "Canada"
        ]
      },
      "phone": "+19055222999",
      "display_phone": "+1 905-522-2999",
      "distance": 1052.1415211374524
    },
    {
      "id": "dxsrhzpSxY9wDGbZxhIjHQ",
      "alias": "the-coop-hamilton",
      "name": "The Coop",
      "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/GuEVBhD1CNCopbN6GKgMsw/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/the-coop-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 43,
      "categories": [
        {
          "alias": "sandwiches",
          "title": "Sandwiches"
        },
        {
          "alias": "chickenshop",
          "title": "Chicken Shop"
        },
        {
          "alias": "poutineries",
          "title": "Poutineries"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.2591337,
        "longitude": -79.8774391
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "274-274 King Street W",
        "address2": "",
        "address3": null,
        "city": "Hamilton",
        "zip_code": "L8P 1J6",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "274-274 King Street W",
          "Hamilton, ON L8P 1J6",
          "Canada"
        ]
      },
      "phone": "+12897782667",
      "display_phone": "+1 289-778-2667",
      "distance": 18.43131711926058
    },
    {
      "id": "752Fv2jKafftvoS3Twkqyg",
      "alias": "hambrgr-hamilton",
      "name": "Hambrgr",
      "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/kELlFVl1FYnGwg1h-yeDPQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/hambrgr-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 203,
      "categories": [
        {
          "alias": "burgers",
          "title": "Burgers"
        },
        {
          "alias": "beerbar",
          "title": "Beer Bar"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 43.25721,
        "longitude": -79.8669
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "49 King William Street",
        "address2": null,
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8R 1A2",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "49 King William Street",
          "Hamilton, ON L8R 1A2",
          "Canada"
        ]
      },
      "phone": "+12893891212",
      "display_phone": "+1 289-389-1212",
      "distance": 858.6720961059851
    },
    {
      "id": "i8nQA6qFkr3TmSCZ1ukbGQ",
      "alias": "electric-diner-hamilton",
      "name": "Electric Diner",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/fkpxsQT9L-E5SUA_GoV6sg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/electric-diner-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 17,
      "categories": [
        {
          "alias": "diners",
          "title": "Diners"
        },
        {
          "alias": "burgers",
          "title": "Burgers"
        },
        {
          "alias": "cocktailbars",
          "title": "Cocktail Bars"
        }
      ],
      "rating": 3.5,
      "coordinates": {
        "latitude": 43.25845,
        "longitude": -79.878
      },
      "transactions": [],
      "location": {
        "address1": "96 George Street",
        "address2": "",
        "address3": null,
        "city": "Hamilton",
        "zip_code": "L8P 3M8",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "96 George Street",
          "Hamilton, ON L8P 3M8",
          "Canada"
        ]
      },
      "phone": "+19055269512",
      "display_phone": "+1 905-526-9512",
      "distance": 106.43795439871784
    },
    {
      "id": "BcOccyfjH_pfu8Z871iSEQ",
      "alias": "ark-and-anchor-hamilton",
      "name": "Ark and Anchor",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/J-ohPx5Qx-lnMudGXWBnHg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/ark-and-anchor-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 14,
      "categories": [
        {
          "alias": "coffee",
          "title": "Coffee & Tea"
        },
        {
          "alias": "bakeries",
          "title": "Bakeries"
        },
        {
          "alias": "cafes",
          "title": "Cafes"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 43.2595,
        "longitude": -79.87812
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "300 King Street W",
        "address2": "",
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8P 1B1",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "300 King Street W",
          "Hamilton, ON L8P 1B1",
          "Canada"
        ]
      },
      "phone": "+19057519345",
      "display_phone": "+1 905-751-9345",
      "distance": 82.37414511053889
    },
    {
      "id": "ZgoVlQmApvjWt-0evoeoGQ",
      "alias": "moodys-hamilton",
      "name": "Moodys",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/t5X50_ZZGaK16kjvmd0Fnw/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/moodys-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 13,
      "categories": [
        {
          "alias": "pizza",
          "title": "Pizza"
        },
        {
          "alias": "gluten_free",
          "title": "Gluten-Free"
        },
        {
          "alias": "italian",
          "title": "Italian"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.25821,
        "longitude": -79.87853
      },
      "transactions": [],
      "location": {
        "address1": "107 George Street",
        "address2": null,
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8P 1E3",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "107 George Street",
          "Hamilton, ON L8P 1E3",
          "Canada"
        ]
      },
      "phone": "+12893096449",
      "display_phone": "+1 289-309-6449",
      "distance": 151.94419171172675
    },
    {
      "id": "ouKTL8ajZ2BGPRf33xwGWA",
      "alias": "pho-nhung-hamilton",
      "name": "Pho Nhung",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/3HU0Ii3CKZeySOQanS3KCg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/pho-nhung-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 16,
      "categories": [
        {
          "alias": "vietnamese",
          "title": "Vietnamese"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 43.26239,
        "longitude": -79.87797
      },
      "transactions": [],
      "location": {
        "address1": "85 Queen St N",
        "address2": null,
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8R 2V5",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "85 Queen St N",
          "Hamilton, ON L8R 2V5",
          "Canada"
        ]
      },
      "phone": "+19055258008",
      "display_phone": "+1 905-525-8008",
      "distance": 321.9290467182559
    },
    {
      "id": "bHecMQ85o3ayw1t9hRA90g",
      "alias": "the-french-hamilton",
      "name": "The French",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/IpfL8CqWQAUg9rjkvBEqzg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/the-french-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 98,
      "categories": [
        {
          "alias": "bistros",
          "title": "Bistros"
        },
        {
          "alias": "french",
          "title": "French"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.25741,
        "longitude": -79.86748
      },
      "transactions": [],
      "price": "$$$",
      "location": {
        "address1": "37 King William Street",
        "address2": "",
        "address3": null,
        "city": "Hamilton",
        "zip_code": "L8R 1A1",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "37 King William Street",
          "Hamilton, ON L8R 1A1",
          "Canada"
        ]
      },
      "phone": "+19055283737",
      "display_phone": "+1 905-528-3737",
      "distance": 814.1051540640244
    },
    {
      "id": "oOxuBeVcfyEExUn2d_FO0A",
      "alias": "smokes-poutinerie-hamilton",
      "name": "Smoke's Poutinerie",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/a65ZJuQzh_ZCAtOqMybw4Q/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/smokes-poutinerie-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 36,
      "categories": [
        {
          "alias": "hotdogs",
          "title": "Fast Food"
        },
        {
          "alias": "poutineries",
          "title": "Poutineries"
        }
      ],
      "rating": 3.5,
      "coordinates": {
        "latitude": 43.25854,
        "longitude": -79.87863
      },
      "transactions": [],
      "price": "$",
      "location": {
        "address1": "112 George Street",
        "address2": "",
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8P 1E3",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "112 George Street",
          "Hamilton, ON L8P 1E3",
          "Canada"
        ]
      },
      "phone": "+12893898779",
      "display_phone": "+1 289-389-8779",
      "distance": 128.9456689732675
    },
    {
      "id": "xwVB61hW9rpyp6wALR4Apg",
      "alias": "berkeley-north-hamilton-2",
      "name": "Berkeley North",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/dR82KlG7oA71lWXG2z7HzA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/berkeley-north-hamilton-2?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 42,
      "categories": [
        {
          "alias": "bars",
          "title": "Bars"
        },
        {
          "alias": "newcanadian",
          "title": "Canadian (New)"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 43.2574045478956,
        "longitude": -79.8677145254958
      },
      "transactions": [],
      "price": "$$$",
      "location": {
        "address1": "31 King William Street",
        "address2": "",
        "address3": null,
        "city": "Hamilton",
        "zip_code": "L8R 1A1",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "31 King William Street",
          "Hamilton, ON L8R 1A1",
          "Canada"
        ]
      },
      "phone": "+19055225858",
      "display_phone": "+1 905-522-5858",
      "distance": 792.5444575825189
    },
    {
      "id": "XqZOIEbNX7mdIg1Cwb1RWw",
      "alias": "famous-recipe-hamilton",
      "name": "Famous Recipe",
      "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Py1R6K7JXNu3KPfGxsuFAA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/famous-recipe-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 9,
      "categories": [
        {
          "alias": "caribbean",
          "title": "Caribbean"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 43.2580694,
        "longitude": -79.8740306
      },
      "transactions": [],
      "location": {
        "address1": "158 King Street W",
        "address2": "",
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8P 1A6",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "158 King Street W",
          "Hamilton, ON L8P 1A6",
          "Canada"
        ]
      },
      "phone": "+12893899740",
      "display_phone": "+1 289-389-9740",
      "distance": 283.12798300914505
    },
    {
      "id": "1E7ww2xRfk6GKEw5HRg4qg",
      "alias": "papagayo-restaurant-hamilton",
      "name": "Papagayo Restaurant",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/EERAEASSNCPJgRdCYBnRMQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/papagayo-restaurant-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 10,
      "categories": [
        {
          "alias": "mexican",
          "title": "Mexican"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.25902,
        "longitude": -79.87646
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "246 King Street W",
        "address2": "",
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8P 1A9",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "246 King Street W",
          "Hamilton, ON L8P 1A9",
          "Canada"
        ]
      },
      "phone": "+19055250309",
      "display_phone": "+1 905-525-0309",
      "distance": 63.27330748627651
    },
    {
      "id": "r3mtyebUU9fgPQx-jWIanA",
      "alias": "the-works-hamilton-4",
      "name": "The Works",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/t1Qos6lcGrMpBrq6DgY5Zg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/the-works-hamilton-4?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 37,
      "categories": [
        {
          "alias": "burgers",
          "title": "Burgers"
        },
        {
          "alias": "wine_bars",
          "title": "Wine Bars"
        },
        {
          "alias": "beerbar",
          "title": "Beer Bar"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.2574961574363,
        "longitude": -79.8712256690338
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "2 King Street W",
        "address2": "Unit 230",
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8P 1A2",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "2 King Street W",
          "Unit 230",
          "Hamilton, ON L8P 1A2",
          "Canada"
        ]
      },
      "phone": "+19055408500",
      "display_phone": "+1 905-540-8500",
      "distance": 517.5164919251919
    },
    {
      "id": "TxrfCuyQThzsFUlcFqdqSw",
      "alias": "saint-james-espresso-bar-and-eatery-hamilton-2",
      "name": "Saint James Espresso Bar & Eatery",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/-T6LAsL5n5Sa-EyW5vDq7A/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/saint-james-espresso-bar-and-eatery-hamilton-2?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 57,
      "categories": [
        {
          "alias": "cafes",
          "title": "Cafes"
        },
        {
          "alias": "bakeries",
          "title": "Bakeries"
        },
        {
          "alias": "bars",
          "title": "Bars"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 43.26098,
        "longitude": -79.86693
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "170 James Street N",
        "address2": null,
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8R 2L1",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "170 James Street N",
          "Hamilton, ON L8R 2L1",
          "Canada"
        ]
      },
      "phone": "+12893896565",
      "display_phone": "+1 289-389-6565",
      "distance": 856.5561693429133
    },
    {
      "id": "7LaTBlqKxftS-Or25dGGjQ",
      "alias": "bastonis-shawarma-and-grill-hamilton-2",
      "name": "Bastoni's Shawarma & Grill",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/ibRtkPrW3n4anHWQ0rCpHA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/bastonis-shawarma-and-grill-hamilton-2?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 21,
      "categories": [
        {
          "alias": "mideastern",
          "title": "Middle Eastern"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.25896,
        "longitude": -79.87622
      },
      "transactions": [],
      "location": {
        "address1": "234 King Street W",
        "address2": "",
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8P 1A9",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "234 King Street W",
          "Hamilton, ON L8P 1A9",
          "Canada"
        ]
      },
      "phone": "+12898600177",
      "display_phone": "+1 289-860-0177",
      "distance": 85.36324610898126
    },
    {
      "id": "CH4A4Aa--t0A7bP1VfkMrA",
      "alias": "charred-chicken-hamilton",
      "name": "Charred Chicken",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/VejRQorX6SXwiun98MoEPA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/charred-chicken-hamilton?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 120,
      "categories": [
        {
          "alias": "bbq",
          "title": "Barbeque"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 43.2627364,
        "longitude": -79.8663839
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "244 James Street N",
        "address2": "",
        "address3": "",
        "city": "Hamilton",
        "zip_code": "L8R 2L2",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "244 James Street N",
          "Hamilton, ON L8R 2L2",
          "Canada"
        ]
      },
      "phone": "+12893960662",
      "display_phone": "+1 289-396-0662",
      "distance": 964.3461930123414
    },
    {
      "id": "Fkm6WTO7-auG5V4NtzpvRA",
      "alias": "amigos-hamilton-2",
      "name": "Amigos",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/qPtXKKbJc0r5tvyWnsYcTg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/amigos-hamilton-2?adjust_creative=NPbfaNQ7HsnQjUt6p2uy-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NPbfaNQ7HsnQjUt6p2uy-A",
      "review_count": 12,
      "categories": [
        {
          "alias": "mexican",
          "title": "Mexican"
        },
        {
          "alias": "latin",
          "title": "Latin American"
        },
        {
          "alias": "cocktailbars",
          "title": "Cocktail Bars"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 43.25825,
        "longitude": -79.87868
      },
      "transactions": [],
      "location": {
        "address1": "109 George Street",
        "address2": "",
        "address3": null,
        "city": "Hamilton",
        "zip_code": "L8P 1E3",
        "country": "CA",
        "state": "ON",
        "display_address": [
          "109 George Street",
          "Hamilton, ON L8P 1E3",
          "Canada"
        ]
      },
      "phone": "+19052671532",
      "display_phone": "+1 905-267-1532",
      "distance": 156.29169160867355
    }
  ],
  "total": 208,
  "region": {
    "center": {
      "longitude": -79.87721174955368,
      "latitude": 43.259125842121065
    }
  }
}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# PATH TO ID, entries 0-19, n = 20
yelpdata['businesses'][0]['id']

# PATH TO NAME, entries 0-19, n = 20
yelpdata['businesses'][0]['name']

# PATH TO LATITUDE, entries 0-19, n = 20
yelpdata['businesses'][0]['coordinates']['latitude']

# PATH TO LONGITUDE, entries 0-19, n = 20
yelpdata['businesses'][0]['coordinates']['longitude']

# PATH TO RATING, entries 0-19, n = 20
yelpdata['businesses'][0]['rating']

# PATH TO REVIEW_COUNT, entries 0-19, n = 20
yelpdata['businesses'][0]['review_count']

# PATH TO CATEGORIES, entries 0-19, n = 20
yelpdata['businesses'][0]['categories']

# %% [markdown]
# Put your parsed results into a DataFrame

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
Yelp had more data, including the valuable review counts and ratings attractive to consumers using their website. 
However, when searching for a specific type of place, Foursquare was more precise, using 5-digit codes to signify what category you were searching.

# %%
# SORT YELP_DF to find top-rated restaurants
rating_df = yelp_df.sort_values(by='rating', ascending=False)

# %%
# 56 restaurants had 5.0, the highest possible rating, although most had only 1 review. 
# The highest review count for 5.0 ratings was 7, held by 8 restaurants.
rating_df.head(56)
# Out:
#       rating  review_count   latitude  longitude
# 611      5.0           1.0  43.252911 -79.822172
# 751      5.0           1.0  43.262743 -79.917147
# 548      5.0           1.0  43.247565 -79.818050
# 922      5.0           7.0  43.244447 -79.819230
# 397      5.0           1.0  43.258025 -79.913839
# 924      5.0           1.0  43.244447 -79.819230
# 925      5.0           5.0  43.244447 -79.819230
# 166      5.0           1.0  43.262714 -79.915806
# 927      5.0           1.0  43.244447 -79.819230
# 933      5.0           2.0  43.265581 -79.949656
# 608      5.0           7.0  43.252911 -79.822172
# 274      5.0           1.0  43.256569 -79.901169
# 610      5.0           5.0  43.252911 -79.822172
# 613      5.0           1.0  43.252911 -79.822172
# 614      5.0           7.0  43.251478 -79.816021
# 615      5.0           5.0  43.251478 -79.816021
# 616      5.0           1.0  43.251478 -79.816021
# 617      5.0           1.0  43.251478 -79.816021
# ...
